# %%
available_details = api.available_details()

# %% [markdown]
# KpfrzOieUl2tJUU

# %%
from kindwise import PlantApi, PlantIdentification
import base64
from datetime import datetime
from dotenv import load_dotenv
load_dotenv()         
import os

api = PlantApi(api_key="PGWB5whk4cFI6aNSglS7IYsod7uBN1xdDLWUF3cnTtFdkATbme")

details = ['common_names', 'url', 'description', 'synonyms', 'edible_parts', 'propagation_methods', 'watering', 'best_watering',  'taxonomy', 'best_light_condition', 'best_soil_type', 'cultural_significance', 'image']
latitude_longitude  = (53.282275, -6.116891)
language = ['en']
date_time = datetime.now()

with open('PXL_20250712_111253850.jpg', 'rb') as image:
    identification: PlantIdentification = api.identify(
        image.read(),
        details=details,
        language=language,
        latitude_longitude=latitude_longitude,
        date_time=date_time,
        # extra_get_params={"classification": "culinary_herb"}
    )

identification
# Out:
# PlantIdentification(access_token='mBbkIzWtfZVmckm', model_version='plant_id:5.0.0', custom_id=None, input=PlantInput(images=['https://plant.id/media/imgs/f4c7cbccbfa740f1ae3a60fca2735155.jpg'], datetime=datetime.datetime(2025, 7, 12, 12, 18, 53, 23092), latitude=53.282275, longitude=-6.116891, similar_images=True, classification_level=None, classification_raw=False), result=PlantResult(is_plant=ResultEvaluation(probability=0.99828184, binary=True, threshold=0.5), is_healthy=None, classification=Classification(suggestions=[Suggestion(id='88f03d1ff947b7fe', name='Mentha spicata', probability=0.4567, similar_images=[SimilarImage(id='4e28cdd62393caf18206685134463a2ed4401216', url='https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/4e2/8cdd62393caf18206685134463a2ed4401216.jpeg', similarity=0.723, url_small='https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/4e2/8cdd62393caf18206685134463a2ed4401216.small.jpeg', license_name='CC BY-NC-SA 4.0', license_url='https://creativecommons.org/licenses/by-nc-sa/4.0/', citation='FlowerChecker s.r.o.'), SimilarImage(id='ddec45be1807779fc85ebd2b16846066e0ecea2d', url='https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/dde/c45be1807779fc85ebd2b16846066e0ecea2d.jpeg', similarity=0.71, url_small='https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/dde/c45be1807779fc85ebd2b16846066e0ecea2d.small.jpeg', license_name='CC BY 4.0', license_url='https://creativecommons.org/licenses/by/4.0/', citation='edoardo tanello')], details={'common_names': ['spearmint'], 'taxonomy': {'class': 'Magnoliopsida', 'genus': 'Mentha', 'order': 'Lamiales', 'family': 'Lamiaceae', 'phylum': 'Tracheophyta', 'kingdom': 'Plantae'}, 'url': 'https://en.wikipedia.org/wiki/Spearmint', 'description': {'value': 'Spearmint, also known as garden mint, common mint, lamb mint and mackerel mint, is a species of mint, Mentha spicata (, native to Europe and southern temperate Asia, extending from Ireland in the west to southern China in the east. It is naturalized in many other temperate parts of the world, including northern and southern Africa, North America, and South America. It is used as a flavouring in food and herbal teas. The aromatic oil, called oil of spearmint, is also used as a flavoring and sometimes as a scent.\nThe species and its subspecies have many synonyms, including Mentha crispa, Mentha crispata, and Mentha viridis.', 'citation': 'https://en.wikipedia.org/wiki/Spearmint', 'license_name': 'CC BY-SA 3.0', 'license_url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, 'synonyms': ['Mentha cordifolia', 'Mentha crispa var. crispata f. reticulata', 'Mentha crispata', 'Mentha longifolia subsp. viridis', 'Mentha rubicunda', 'Mentha spicata', 'Mentha sylvestris subsp. viridis', 'Mentha viridis', 'Mentha viridis var. angustifolia', 'Mentha x cordifolia', 'Mentha x villosa var. cordifolia'], 'image': {'value': 'https://plant-id.ams3.cdn.digitaloceanspaces.com/knowledge_base/wikidata/649/649e9e16bd3397a7a92546f848468071a2b60a42.jpg', 'citation': '//commons.wikimedia.org/wiki/User:LivingShadow', 'license_name': 'CC BY-SA 3.0', 'license_url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, 'edible_parts': ['leaves'], 'watering': {'max': 3, 'min': 2}, 'propagation_methods': ['cuttings', 'seeds'], 'best_light_condition': 'This plant thrives in full sun to partial shade. Ideally, it should receive at least 6 hours of direct sunlight each day for optimal growth. However, it can tolerate some shade, especially in hotter climates where too much direct sunlight might cause the leaves to wilt. If grown indoors, place it near a sunny window where it can get plenty of light.', 'best_soil_type': 'For optimal growth, this plant prefers well-draining, loamy soil. It can tolerate a range of soil types, including sandy and clay soils, as long as they are well-drained. Adding organic matter like compost can improve soil structure and fertility, providing the nutrients it needs to t ...

# %%
PlantIdentification
# Out:
# kindwise.plant.PlantIdentification

# %%
plant = identification.result.classification.suggestions[0].details

# %%
plant
# Out:
# {'common_names': ['English lavender', 'Lavender', 'Common Lavender'],
#  'taxonomy': {'class': 'Magnoliopsida',
#   'genus': 'Lavandula',
#   'order': 'Lamiales',
#   'family': 'Lamiaceae',
#   'phylum': 'Tracheophyta',
#   'kingdom': 'Plantae'},
#  'url': 'https://en.wikipedia.org/wiki/Lavandula_angustifolia',
#  'description': {'value': 'Lavandula angustifolia, formerly L. officinalis, is a flowering plant in the family Lamiaceae, native to the Mediterranean (Spain, France, Italy, Croatia etc.). Its common names include lavender, true lavender and English lavender (though not native to England); also garden lavender, common lavender and narrow-leaved lavender.',
#   'citation': 'https://en.wikipedia.org/wiki/Lavandula_angustifolia',
#   'license_name': 'CC BY-SA 3.0',
#   'license_url': 'https://creativecommons.org/licenses/by-sa/3.0/'},
#  'synonyms': ['Lavandula angustfolia',
#   'Lavandula delphinensis',
#   'Lavandula fragrans',
#   'Lavandula officinalis',
#   'Lavandula vera var. ligustica'],
#  'image': {'value': 'https://plant-id.ams3.cdn.digitaloceanspaces.com/knowledge_base/wikidata/28f/28fab4a8696d771535df7829286b1986cf1917aa.jpg',
#   'citation': None,
#   'license_name': 'CC0',
#   'license_url': 'https://creativecommons.org/publicdomain/zero/1.0/'},
#  'edible_parts': None,
#  'watering': {'max': 2, 'min': 1},
#  'propagation_methods': ['cuttings', 'seeds'],
#  'best_light_condition': 'This plant prefers full sun to partial shade. It needs at least six hours of direct sunlight each day to grow well. In regions with very hot summers, some afternoon shade can help prevent the plant from becoming stressed. However, too much shade can result in leggy growth and fewer flowers.',
#  'best_soil_type': 'The ideal soil for this plant is well-draining and slightly alkaline. Sandy or loamy soils are best, as they prevent water from pooling around the roots. Adding some gravel or sand to the soil can improve drainage. Avoid heavy clay soils, which retain too much moisture and can cause root problems.',
#  'cultural_significance': 'This plant has a rich cultural significance, especially in Mediterranean regions. It has been used for centuries in traditional medicine, religious ceremonies, and as a symbol of purity and cleanliness. Its fragrant flowers are often associated with relaxation and are used in various cultural rituals and practices.',
#  'best_watering': "Watering this plant requires a balanced approach. It thrives with moderate watering, meaning the soil should be allowed to dry out between waterings. Overwatering can lead to root rot, so it's important to ensure good drainage. During the growing season, water the plant deeply but infrequently. In the winter, reduce watering as the plant's growth slows down.",
#  'language': 'en',
#  'entity_id': '7dc6583f7bcf6acb'}

# %%
plant["taxonomy"]
# Out:
# {'class': 'Magnoliopsida',
#  'genus': 'Lavandula',
#  'order': 'Lamiales',
#  'family': 'Lamiaceae',
#  'phylum': 'Tracheophyta',
#  'kingdom': 'Plantae'}

# %%
final_identification: PlantIdentification = api.get_identification("nTs6cZKErodE0YJ", details=details)
final_identification.result.classification.suggestions[0].details
# Out:
# {'common_names': ['pinnate dahlia', 'Garden Dahlia', 'Dahlia'],
#  'taxonomy': {'class': 'Magnoliopsida',
#   'genus': 'Dahlia',
#   'order': 'Asterales',
#   'family': 'Asteraceae',
#   'phylum': 'Tracheophyta',
#   'kingdom': 'Plantae'},
#  'url': 'https://en.wikipedia.org/wiki/Dahlia_pinnata',
#  'description': {'value': 'Dahlia pinnata (D. × pinnata) is a species in the genus Dahlia, family Asteraceae, with the common name garden dahlia. It is the type species of the genus and is widely cultivated.',
#   'citation': 'https://en.wikipedia.org/wiki/Dahlia_pinnata',
#   'license_name': 'CC BY-SA 3.0',
#   'license_url': 'https://creativecommons.org/licenses/by-sa/3.0/'},
#  'synonyms': ['Bidens variabilis',
#   'Coreopsis crassifolia',
#   'Coreopsis georgina',
#   'Dahlia astrantiaeflora',
#   'Dahlia astrantiiflora',
#   'Dahlia barkeriae',
#   'Dahlia crocata',
#   'Dahlia hybrida',
#   'Dahlia mexicana',
#   'Dahlia nana',
#   'Dahlia pinnata subsp. variabilis',
#   'Dahlia pinnata var. nana',
#   'Dahlia pinnata var. pinnata',
#   'Dahlia pinnata var. variabilis',
#   'Dahlia purpurea',
#   'Dahlia purpurea var. flavescens',
#   'Dahlia purpurea var. lilacina',
#   'Dahlia purpurea var. pallida',
#   'Dahlia purpurea var. purpurea',
#   'Dahlia purpurea var. rubra',
#   'Dahlia pusilla',
#   'Dahlia rosea',
#   'Dahlia royleana',
#   'Dahlia sambucifolia',
#   'Dahlia sphondyliifolia',
#   'Dahlia superflua',
#   'Dahlia variabilis',
#   'Dahlia variabilis var. microcephala',
#   'Dahlia xpinnata',
#   'Dahlia xvariabilis',
#   'Dahlia ×cultorum subsp. nud',
#   'Dahliavariabilis',
#   'Georgia superflua',
#   'Georgia superflua var. flavescens',
#   'Georgia superflua var. lilacina',
#   'Georgia superflua var. purpurea',
#   'Georgia superflua var. rubra',
#   'Georgia superflua var. superflua',
#   'Georgia variabilis',
#   'Georgina astrantiaeflora',
#   'Georgina astrantiaeflota',
#   'Georgina astrantiiflora',
#   'Georgina astrantiiflota',
#   'Georgina crocata',
#   'Georgina purpurea',
#   'Georgina rosea',
#   'Georgina superflua',
#   'Georgina superflua var. flavescens',
#   'Georgina superflua var. lilacina',
#   'Georgina superflua var. pallida',
#   'Georgina superflua var. purpurea',
#   'Georgina superflua var. rubra',
#   'Georgina superflua var. superflua',
#   'Georgina variabilis',
#   'Georgina variabilis var. lilacina',
#   'Georgina variabilis var. pallida',
#   'Georgina variabilis var. purpurea'],
#  'image': {'value': 'https://plant-id.ams3.cdn.digitaloceanspaces.com/knowledge_base/wikidata/de3/de3032aab6c210a7f4643426b397e45502b5119b.jpg',
#   'citation': '//commons.wikimedia.org/wiki/User:W._Bulach',
#   'license_name': 'CC BY-SA 4.0',
#   'license_url': 'https://creativecommons.org/licenses/by-sa/4.0/'},
#  'edible_parts': ['flowers', 'root'],
#  'watering': None,
#  'propagation_methods': ['division', 'seeds'],
#  'best_light_condition': 'This plant thrives in full sun, requiring at least six to eight hours of direct sunlight each day. While it can tolerate partial shade, too little light can result in fewer blooms and leggy growth. In regions with extremely hot climates, some afternoon shade can help protect the plant from scorching. Ensuring adequate light is crucial for healthy growth and vibrant flowers.',
#  'best_soil_type': "Well-draining soil is essential for this plant's health. A mix of loamy soil enriched with organic matter like compost or well-rotted manure works best. The soil should be slightly acidic to neutral, with a pH range of 6.0 to 7.5. Good drainage prevents root rot and other water-related issues. Adding sand or perlite can improve soil structure and drainage if needed.",
#  'cultural_significance': "This plant holds cultural significance in various parts of the world. In Mexico, it is the national flower and symbolizes elegance and dignity. It has also been associated with themes of inner strength and creativity. The plant's vibrant and diverse blooms make it a popular choice for celebrations and decorative purposes, reflecting its importance in cultural traditions.",
#  'best_watering': "Watering should be done consistently to keep the soil moist but not waterlogged. It's best to water deeply once or twice a week, depending on the weather and soil conditions. During hot, dry periods, more frequent watering may be necessary. Early morning is the ideal time to water, as it allows the plant to absorb moisture before the heat of the day. Avoid overhead watering to reduce the risk of fungal diseases.",
#  'language': 'en',
#  'entity_id': 'd7d8fb9aa0d2f2ec'}

# %%
final_identification: PlantIdentification = api.get_identification("AGN0xkIpaM1xBJ2", details=details)
final_identification.result.classification.suggestions[0].details
# Out:
# {'common_names': ['English lavender', 'Lavender', 'Common Lavender'],
#  'taxonomy': {'class': 'Magnoliopsida',
#   'genus': 'Lavandula',
#   'order': 'Lamiales',
#   'family': 'Lamiaceae',
#   'phylum': 'Tracheophyta',
#   'kingdom': 'Plantae'},
#  'url': 'https://en.wikipedia.org/wiki/Lavandula_angustifolia',
#  'description': {'value': 'Lavandula angustifolia, formerly L. officinalis, is a flowering plant in the family Lamiaceae, native to the Mediterranean (Spain, France, Italy, Croatia etc.). Its common names include lavender, true lavender and English lavender (though not native to England); also garden lavender, common lavender and narrow-leaved lavender.',
#   'citation': 'https://en.wikipedia.org/wiki/Lavandula_angustifolia',
#   'license_name': 'CC BY-SA 3.0',
#   'license_url': 'https://creativecommons.org/licenses/by-sa/3.0/'},
#  'synonyms': ['Lavandula angustfolia',
#   'Lavandula delphinensis',
#   'Lavandula fragrans',
#   'Lavandula officinalis',
#   'Lavandula vera var. ligustica'],
#  'image': {'value': 'https://plant-id.ams3.cdn.digitaloceanspaces.com/knowledge_base/wikidata/28f/28fab4a8696d771535df7829286b1986cf1917aa.jpg',
#   'citation': None,
#   'license_name': 'CC0',
#   'license_url': 'https://creativecommons.org/publicdomain/zero/1.0/'},
#  'edible_parts': None,
#  'watering': {'max': 2, 'min': 1},
#  'propagation_methods': ['cuttings', 'seeds'],
#  'best_light_condition': 'This plant prefers full sun to partial shade. It needs at least six hours of direct sunlight each day to grow well. In regions with very hot summers, some afternoon shade can help prevent the plant from becoming stressed. However, too much shade can result in leggy growth and fewer flowers.',
#  'best_soil_type': 'The ideal soil for this plant is well-draining and slightly alkaline. Sandy or loamy soils are best, as they prevent water from pooling around the roots. Adding some gravel or sand to the soil can improve drainage. Avoid heavy clay soils, which retain too much moisture and can cause root problems.',
#  'cultural_significance': 'This plant has a rich cultural significance, especially in Mediterranean regions. It has been used for centuries in traditional medicine, religious ceremonies, and as a symbol of purity and cleanliness. Its fragrant flowers are often associated with relaxation and are used in various cultural rituals and practices.',
#  'best_watering': "Watering this plant requires a balanced approach. It thrives with moderate watering, meaning the soil should be allowed to dry out between waterings. Overwatering can lead to root rot, so it's important to ensure good drainage. During the growing season, water the plant deeply but infrequently. In the winter, reduce watering as the plant's growth slows down.",
#  'language': 'en',
#  'entity_id': '7dc6583f7bcf6acb'}

# %%
from IPython.display import Image, display
for suggestion in final_identification.result.classification.suggestions:
    print("Name: ",suggestion.name)
    print("Probability: ",suggestion.probability)
    print("Details: ",suggestion.details)
    display(Image(url=suggestion.similar_images[0].url))
# Out:
# Name:  Lavandula angustifolia
# Probability:  0.9082
# Details:  {'language': 'en', 'entity_id': '7dc6583f7bcf6acb'}
# <img src="https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/b2a/80522b8775d84a5e533bfc8a6060e02e5e0f5.jpeg"/>
# Name:  Verbena
# Probability:  0.0453
# Details:  {'language': 'en', 'entity_id': 'f9fb718bced2919f'}
# <img src="https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/f5f/080703b5030c71e1c0036acead9dbbb5e847d.jpeg"/>
# Name:  Erysimum
# Probability:  0.0202
# Details:  {'language': 'en', 'entity_id': '94d0a430e6903f82'}
# <img src="https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/d16/36606725d1ded80f2af7f5519118925203010.jpeg"/>
# Name:  Limonium
# Probability:  0.0159
# Details:  {'language': 'en', 'entity_id': '320ba24b8d0363b2'}
# <img src="https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/9ee/58c5c048eb6222aa5f5fb8a0418a7c57c0782.jpeg"/>
# Name:  Linaria
# Probability:  0.0104
# Details:  {'language': 'en', 'entity_id': '3218b08664174840'}
# <img src="https://plant-id.ams3.cdn.digitaloceanspaces.com/similar_images/5/70f/55f5f15651b77480de6ee8da407746e8cac12.jpeg"/>
